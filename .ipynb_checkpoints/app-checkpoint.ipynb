# %%
import pandas as pd

df = pd.read_csv(
    r"C:\data\complaints.csv",
    nrows=5
)

print(df.columns.tolist())
# Out:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']

# %%
df = pd.read_csv(
    r"C:\data\complaints.csv",
    usecols=["Consumer complaint narrative"],
    nrows=10000
)

documents = (
    df["Consumer complaint narrative"]
    .fillna("")
    .tolist()
)

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\data\complaints.csv",
    usecols=["Consumer complaint narrative"],
    nrows=10000   # adjust if needed
)

df = df.dropna()

documents = df["Consumer complaint narrative"].tolist()

print(f"Loaded {len(documents)} complaints")
# Out:
# Loaded 2 complaints

# %%
print(type(documents))
print(len(documents))
# Out:
# <class 'list'>
# 2

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer(
    "all-MiniLM-L6-v2"
)

embeddings = embedding_model.encode(
    documents,
    convert_to_numpy=True,
    show_progress_bar=True
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import faiss
import numpy as np

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(
    embeddings.astype(np.float32)
)

# %%
metadata = []

for doc in documents:
    metadata.append({
        "text": doc
    })

# %%
print("documents" in globals())
# Out:
# True

# %%
embeddings = embedding_model.encode(
    documents,
    convert_to_numpy=True,
    show_progress_bar=True
)

print(embeddings.shape)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# (2, 384)

# %%
def retrieve_chunks(question, k=2):

    query_embedding = embedding_model.encode(
        [question],
        convert_to_numpy=True
    )

    distances, indices = index.search(
        query_embedding.astype(np.float32),
        k
    )

    return [
        metadata[idx]
        for idx in indices[0]
    ]

# %%
results = retrieve_chunks(
    "What are the common complaints?"
)

print(results[0]["text"][:300])
# Out:
# Subject : Dispute of Unauthorized Hard Inquiries on Credit Report XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Fl XXXX XX/XX/XXXX Social Security XXXX XX/XX/XXXX Consumer Financial Protection Bureau XXXX XXXX XXXX XXXX, IA XXXX To Whom It May Concern, I am writing to formally dispute unauthorized hard i

# %%
print(type(documents))
print(len(documents))
print(documents[0][:200])
# Out:
# <class 'list'>
# 2
# XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Apt XXXX, XXXX, TX XXXX XXXX : XX/XX/XXXX TransUnion Consumer Solutions XXXX XXXX XXXX XXXX, PA XXXX XXXX : XXXX Re : Security Freeze Request Dear Sir/Madam, I,

# %%
chunks = retrieve_chunks(
    "What are the common complaints?"
)

print(chunks[0]["text"][:500])
# Out:
# Subject : Dispute of Unauthorized Hard Inquiries on Credit Report XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Fl XXXX XX/XX/XXXX Social Security XXXX XX/XX/XXXX Consumer Financial Protection Bureau XXXX XXXX XXXX XXXX, IA XXXX To Whom It May Concern, I am writing to formally dispute unauthorized hard inquiries that have appeared on my credit report. I did not authorize these inquiries, and they are negatively impacting my credit score. Despite previous attempts to resolve this matter with the credi

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="distilgpt2"
)

def generate_answer(prompt):

    result = generator(
        prompt,
        max_new_tokens=100,
        truncation=True,
        do_sample=False
    )

    generated_text = result[0]["generated_text"]

    # Remove prompt from returned text
    answer = generated_text[len(prompt):].strip()

    return answer
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]

# %%
# %whos
# Out:
# Variable              Type                      Data/Info
# ---------------------------------------------------------
# SentenceTransformer   ABCMeta                   <class 'sentence_transfor<...>del.SentenceTransformer'>
# answer_output         Textbox                   <gradio.components.textbo<...>ct at 0x000001D315F42C10>
# ask_button            Button                    <gradio.components.button<...>ct at 0x000001D315F42990>
# ask_question          function                  <function ask_question at 0x000001D315D5B270>
# chunks                list                      n=2
# clear_all             function                  <function clear_all at 0x000001D315D5B110>
# clear_button          Button                    <gradio.components.button<...>ct at 0x000001D315F42AD0>
# demo                  Blocks                    Gradio Blocks instance: 2<...>ct at 0x000001D315F42D50>
# df                    DataFrame                 Shape: (2, 1)
# dimension             int                       384
# doc                   str                       Subject : Dispute of Unau<...> \n\nSincerely, XXXX XXXX
# documents             list                      n=2
# embedding_model       SentenceTransformer       SentenceTransformer(\n  (<...>\n  (2): Normalize({})\n)
# embeddings            ndarray                   2x384: 768 elems, type `float32`, 3072 bytes
# faiss                 module                    <module 'faiss' from 'C:\<...>ges\\faiss\\__init__.py'>
# generate_answer       function                  <function generate_answer at 0x000001D315D5B740>
# generator             TextGenerationPipeline    TextGenerationPipeline: {<...>t_modalities': ('text',)}
# gr                    module                    <module 'gradio' from 'C:<...>es\\gradio\\__init__.py'>
# index                 IndexFlatL2               <faiss.swigfaiss.IndexFla<...> at 0x000001D2F250A270> >
# metadata              list                      n=2
# np                    module                    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd                    module                    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# pipeline              function                  <function pipeline at 0x000001D2F4227CC0>
# question_input        Textbox                   <gradio.components.textbo<...>ct at 0x000001D315F42710>
# rag_pipeline          function                  <function rag_pipeline at 0x000001D315D5BB60>
# results               list                      n=2
# retrieve_chunks       function                  <function retrieve_chunks at 0x000001D2F428FA00>
# sources_output        Textbox                   <gradio.components.textbo<...>ct at 0x000001D315F42D50>
# time                  module                    <module 'time' (built-in)>

# %%
def generate_answer(prompt):

    result = generator(
        prompt,
        max_new_tokens=100,
        do_sample=False,
        truncation=True
    )

    generated_text = result[0]["generated_text"]

    # remove prompt from returned text
    answer = generated_text.replace(prompt, "").strip()

    return answer

# %%
answer, chunks = rag_pipeline(
    "Why are customers complaining about unauthorized charges?"
)

print(answer)
print(chunks)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] This is a friendly reminder - the current text generation call has exceeded the model's predefined maximum length (1024). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'text': 'Subject : Dispute of Unauthorized Hard Inquiries on Credit Report XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Fl XXXX XX/XX/XXXX Social Security XXXX XX/XX/XXXX Consumer Financial Protection Bureau XXXX XXXX XXXX XXXX, IA XXXX To Whom It May Concern, I am writing to formally dispute unauthorized hard inquiries that have appeared on my credit report. I did not authorize these inquiries, and they are negatively impacting my credit score. Despite previous attempts to resolve this matter with the credit bureaus, these inquiries remain on my report. \n\nThe disputed hard inquiries are as follows : XXXX. XXXXXXXX XXXX XXXX XXXXXXXX Date of Inquiry : XX/XX/XXXX XXXX XXXX XXXX XXXX XXXX Issue : I did not apply for credit with this company, and I did not authorize this inquiry. \n\nXXXX. XXXX XXXX XXXX Date of Inquiry : XX/XX/XXXX XXXX XXXX XXXX XXXX XXXX, Florida XXXX Issue : I have no relationship with this creditor and never consented to this inquiry. \n\nXXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Hard Inquiries ) [ 15 U.S. Code 1602p ] Under the Fair Credit Reporting Act ( FCRA ), hard inquiries require my explicit authorization. Since I did not authorize these inquiries, I request their immediate removal from my credit file. \n\nI have previously contacted the credit bureaus regarding this matter but have not received a satisfactory resolution. As the Consumer Financial Protection Bureau has taken action against credit bureaus for inadequate dispute handling, I am now escalating my complaint to your office for investigation and enforcement. \n\nEnclosed are copies of my credit report with the unauthorized inquiries highlighted, as well as any supporting documents. I kindly request that you take action to have these inquiries removed and ensure that the credit bureaus comply with federal regulations. \n\nPlease acknowledge receipt of this dispute and inform me of any further steps required. I appreciate your prompt attention to this matter. \n\nSincerely, XXXX XXXX'}, {'text': 'XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Apt XXXX, XXXX, TX XXXX XXXX : XX/XX/XXXX TransUnion Consumer Solutions XXXX XXXX XXXX XXXX, PA XXXX XXXX : XXXX Re : Security Freeze Request Dear Sir/Madam, I, XXXX XXXX XXXX XXXX XXXX XXXX Social Security XXXX XXXX, a resident of XXXX XXXX XXXX XXXXXXXX XXXX XXXX  XXXX, TX XXXX, submit this affidavit to request a security freeze on my credit report. Pursuant to my rights under applicable federal and state laws, including but not limited to the Fair Credit Reporting Act and any other relevant regulations, I hereby formally request that a Security Freeze be placed on my credit file immediately. \nAffidavit : Applicant Identification : Full Name : XXXX XXXX XXXX XXXX Social Security Number : XXXX Date of Birth : XX/XX/XXXX Current Address : XXXX XXXX XXXX XXXX Apt XXXX, XXXX XXXX TX XXXX XXXX XXXX Request : o I request that a security freeze be placed on my credit report to prevent unauthorized third-party access, except for those legally authorized or with my explicit consent. \no This freeze should remain in place until I personally request its removal in writing, in compliance with applicable legal requirements. \nAttached Documentation : I have attached the following documents to verify my identity and process my request : o A copy of my drivers license or government-issued ID.  ...

# %%
def generate_answer(prompt):

    # GPT-2 struggles with very long inputs
    prompt = prompt[:1000]

    result = generator(
        prompt,
        max_new_tokens=100,
        do_sample=False,
        truncation=True
    )

    generated_text = result[0]["generated_text"]

    return generated_text.replace(prompt, "").strip()

# %%
def rag_pipeline(question):

    retrieved_chunks = retrieve_chunks(question, k=2)

    context = "\n\n".join(
        chunk["text"][:500]   # limit each chunk
        for chunk in retrieved_chunks
    )

    prompt = f"""
Complaint Records:
{context}

Question:
{question}

Answer:
"""

    answer = generate_answer(prompt)

    return answer, retrieved_chunks

# %%
def retrieve_chunks(question, k=3):

    query_embedding = embedding_model.encode(
        [question],
        convert_to_numpy=True
    )

    distances, indices = index.search(
        query_embedding.astype(np.float32),
        k
    )

    retrieved = []

    for idx in indices[0]:
        retrieved.append(metadata[idx])

    return retrieved

# %%
chunks = retrieve_chunks(
    "Why are customers complaining about unauthorized charges?"
)

print(chunks)
# Out:
# [{'text': 'Subject : Dispute of Unauthorized Hard Inquiries on Credit Report XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Fl XXXX XX/XX/XXXX Social Security XXXX XX/XX/XXXX Consumer Financial Protection Bureau XXXX XXXX XXXX XXXX, IA XXXX To Whom It May Concern, I am writing to formally dispute unauthorized hard inquiries that have appeared on my credit report. I did not authorize these inquiries, and they are negatively impacting my credit score. Despite previous attempts to resolve this matter with the credit bureaus, these inquiries remain on my report. \n\nThe disputed hard inquiries are as follows : XXXX. XXXXXXXX XXXX XXXX XXXXXXXX Date of Inquiry : XX/XX/XXXX XXXX XXXX XXXX XXXX XXXX Issue : I did not apply for credit with this company, and I did not authorize this inquiry. \n\nXXXX. XXXX XXXX XXXX Date of Inquiry : XX/XX/XXXX XXXX XXXX XXXX XXXX XXXX, Florida XXXX Issue : I have no relationship with this creditor and never consented to this inquiry. \n\nXXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Hard Inquiries ) [ 15 U.S. Code 1602p ] Under the Fair Credit Reporting Act ( FCRA ), hard inquiries require my explicit authorization. Since I did not authorize these inquiries, I request their immediate removal from my credit file. \n\nI have previously contacted the credit bureaus regarding this matter but have not received a satisfactory resolution. As the Consumer Financial Protection Bureau has taken action against credit bureaus for inadequate dispute handling, I am now escalating my complaint to your office for investigation and enforcement. \n\nEnclosed are copies of my credit report with the unauthorized inquiries highlighted, as well as any supporting documents. I kindly request that you take action to have these inquiries removed and ensure that the credit bureaus comply with federal regulations. \n\nPlease acknowledge receipt of this dispute and inform me of any further steps required. I appreciate your prompt attention to this matter. \n\nSincerely, XXXX XXXX'}, {'text': 'XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Apt XXXX, XXXX, TX XXXX XXXX : XX/XX/XXXX TransUnion Consumer Solutions XXXX XXXX XXXX XXXX, PA XXXX XXXX : XXXX Re : Security Freeze Request Dear Sir/Madam, I, XXXX XXXX XXXX XXXX XXXX XXXX Social Security XXXX XXXX, a resident of XXXX XXXX XXXX XXXXXXXX XXXX XXXX  XXXX, TX XXXX, submit this affidavit to request a security freeze on my credit report. Pursuant to my rights under applicable federal and state laws, including but not limited to the Fair Credit Reporting Act and any other relevant regulations, I hereby formally request that a Security Freeze be placed on my credit file immediately. \nAffidavit : Applicant Identification : Full Name : XXXX XXXX XXXX XXXX Social Security Number : XXXX Date of Birth : XX/XX/XXXX Current Address : XXXX XXXX XXXX XXXX Apt XXXX, XXXX XXXX TX XXXX XXXX XXXX Request : o I request that a security freeze be placed on my credit report to prevent unauthorized third-party access, except for those legally authorized or with my explicit consent. \no This freeze should remain in place until I personally request its removal in writing, in compliance with applicable legal requirements. \nAttached Documentation : I have attached the following documents to verify my identity and process my request : o A copy of my drivers license or government-issued ID.  ...

# %%
print("embedding_model" in globals())
print("index" in globals())
print("metadata" in globals())
print("retrieve_chunks" in globals())
# Out:
# True
# True
# True
# True

# %%
documents = (
    df["Consumer complaint narrative"]
    .dropna()
    .astype(str)
    .tolist()
)

print(len(documents))
# Out:
# 2

# %%
import gradio as gr
import time

# ==========================================
# RAG PIPELINE
# ==========================================
# Must return:
# answer (str)
# retrieved_chunks (list of dicts)

# Example:
# answer, retrieved_chunks = rag_pipeline(question)

# ==========================================
# STREAMING FUNCTION
# ==========================================

def ask_question(question):

    if not question.strip():
        yield "Please enter a question.", ""
        return

    try:
        answer, retrieved_chunks = rag_pipeline(question)

        # Format sources
        sources_text = ""

        for i, chunk in enumerate(retrieved_chunks[:3], start=1):

            if isinstance(chunk, dict):
                text = chunk.get("text", "")
            else:
                text = str(chunk)

            sources_text += (
                f"Source {i}\n"
                f"{'-'*40}\n"
                f"{text[:1000]}\n\n"
            )

        # Stream answer
        partial_answer = ""

        for word in answer.split():

            partial_answer += word + " "

            time.sleep(0.02)

            yield partial_answer, sources_text

    except Exception as e:

        yield f"Error: {str(e)}", ""

# ==========================================
# CLEAR FUNCTION
# ==========================================

def clear_all():
    return "", "", ""

# ==========================================
# GRADIO UI
# ==========================================

with gr.Blocks(
    title="Complaint RAG Chatbot"
) as demo:

    gr.Markdown(
        """
# Complaint RAG Chatbot

Ask questions about customer complaints.

Features:
- AI-generated answers
- Source transparency
- Streaming responses
- Clear button
"""
    )

    question_input = gr.Textbox(
        label="Your Question",
        placeholder="Why are customers complaining about unauthorized charges?",
        lines=2
    )

    with gr.Row():

        ask_button = gr.Button(
            "Ask",
            variant="primary"
        )

        clear_button = gr.Button(
            "Clear"
        )

    answer_output = gr.Textbox(
        label="AI Generated Answer",
        lines=10
    )

    sources_output = gr.Textbox(
        label="Retrieved Sources",
        lines=15
    )

    ask_button.click(
        fn=ask_question,
        inputs=question_input,
        outputs=[
            answer_output,
            sources_output
        ]
    )

    clear_button.click(
        fn=clear_all,
        outputs=[
            question_input,
            answer_output,
            sources_output
        ]
    )

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\routes.py:1379: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\routes.py:1379: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(type(rag_pipeline))
# Out:
# <class 'function'>

# %%
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
