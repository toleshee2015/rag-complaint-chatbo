# %%
import pandas as pd

df = pd.read_csv(
    r"C:\data\complaints.csv",
    nrows=5
)

print(sample.columns.tolist())
# Out:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']

# %%
print(df.columns.tolist())
# Out:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#   Date received                                            Product  \
# 0    2025-06-20  Credit reporting or other personal consumer re...
# 1    2025-06-20                                    Debt collection
# 2    2025-06-20  Credit reporting or other personal consumer re...
# 3    2025-06-20  Credit reporting or other personal consumer re...
# 4    2025-06-20  Credit reporting or other personal consumer re...
#
#                Sub-product                                 Issue  \
# 0         Credit reporting  Incorrect information on your report
# 1  Telecommunications debt     Attempts to collect debt not owed
# 2         Credit reporting           Improper use of your report
# 3         Credit reporting           Improper use of your report
# 4         Credit reporting  Incorrect information on your report
#
#                                        Sub-issue  \
# 0            Information belongs to someone else
# 1                              Debt is not yours
# 2  Reporting company used your report improperly
# 3  Reporting company used your report improperly
# 4                       Account status incorrect
#
#    Consumer complaint narrative  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                              Company public response  \
# 0                                                NaN
# 1  Company can't verify or dispute the facts in t...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Company State ZIP code  Tags  \
# 0           Experian Information Solutions Inc.    FL    32092   NaN
# 1  Eastern Account Systems of Connecticut, Inc.    FL    342XX   NaN
# 2        TRANSUNION INTERMEDIATE HOLDINGS, INC.    AZ    85225   NaN
# 3           Experian Information Solutions Inc.    AZ    85225   NaN
# 4           Experian Information Solutions Inc.    IL    60628   NaN
#
#    Consumer consent provided? Submitted via Date sent to company  \
# 0                         NaN           Web           2025-06-20
# 1                         NaN           Web           2025-06-20
# 2                         NaN           Web           2025-06-20
# 3                         NaN           Web           2025-06-20
# 4                         NaN           Web           2025-06-20
#
#   Company response to consumer Timely response?  Consumer disputed?  \
# 0                  In progress              Yes                 NaN
# 1      Closed with explanation              Yes                 NaN
# 2                  In progress              Yes                 NaN
# 3                  In progress              Yes                 NaN
# 4                  In progress              Yes                 NaN
#
#    Complaint ID
# 0      14195687
# 1      14195688
# 2      14195689
# 3      14195690
# 4      14195692
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']

# %%
import pandas as pd

cols = pd.read_csv(
    r"C:\data\complaints.csv",
    nrows=0
)

print(cols.columns.tolist())
# Out:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']

# %%
import pandas as pd

sample = pd.read_csv(
    r"C:\data\complaints.csv",
    nrows=5
)

print(sample.columns)
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='str')

# %%
df = pd.read_csv(
    r"C:\data\complaints.csv",
    usecols=["Consumer complaint narrative"],
    nrows=10000
)

documents = (
    df["Consumer complaint narrative"]
    .fillna("")
    .tolist()
)

# %%
import pandas as pd

cols = pd.read_csv(
    r"C:\data\complaints.csv",
    nrows=0
)

print(cols.columns.tolist())
# Out:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\data\complaints.csv",
    usecols=["Consumer complaint narrative"],
    nrows=10000   # adjust if needed
)

df = df.dropna()

documents = df["Consumer complaint narrative"].tolist()

print(f"Loaded {len(documents)} complaints")
# Out:
# Loaded 2 complaints

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\data\complaints.csv",
    usecols=["Consumer complaint narrative"],
    nrows=10000
)

df = df.dropna()

documents = df["Consumer complaint narrative"].tolist()

print(f"Loaded {len(documents)} documents")
print(documents[0][:200])
# Out:
# Loaded 2 documents
# XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Apt XXXX, XXXX, TX XXXX XXXX : XX/XX/XXXX TransUnion Consumer Solutions XXXX XXXX XXXX XXXX, PA XXXX XXXX : XXXX Re : Security Freeze Request Dear Sir/Madam, I,

# %%
print(type(documents))
print(len(documents))
# Out:
# <class 'list'>
# 2

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer(
    "all-MiniLM-L6-v2"
)

embeddings = embedding_model.encode(
    documents,
    convert_to_numpy=True,
    show_progress_bar=True
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import faiss
import numpy as np

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(
    embeddings.astype(np.float32)
)

# %%
metadata = []

for doc in documents:
    metadata.append({
        "text": doc
    })

# %%
print("documents" in globals())
# Out:
# True

# %%
embeddings = embedding_model.encode(
    documents,
    convert_to_numpy=True,
    show_progress_bar=True
)

print(embeddings.shape)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# (2, 384)

# %%
import faiss
import numpy as np

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(
    embeddings.astype(np.float32)
)

print(index.ntotal)
# Out:
# 2

# %%
metadata = [
    {"text": doc}
    for doc in documents
]

# %%
def retrieve_chunks(question, k=2):

    query_embedding = embedding_model.encode(
        [question],
        convert_to_numpy=True
    )

    distances, indices = index.search(
        query_embedding.astype(np.float32),
        k
    )

    return [
        metadata[idx]
        for idx in indices[0]
    ]

# %%
results = retrieve_chunks(
    "What are the common complaints?"
)

print(results[0]["text"][:300])
# Out:
# Subject : Dispute of Unauthorized Hard Inquiries on Credit Report XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Fl XXXX XX/XX/XXXX Social Security XXXX XX/XX/XXXX Consumer Financial Protection Bureau XXXX XXXX XXXX XXXX, IA XXXX To Whom It May Concern, I am writing to formally dispute unauthorized hard i

# %%
print(type(documents))
print(len(documents))
print(documents[0][:200])
# Out:
# <class 'list'>
# 2
# XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX Apt XXXX, XXXX, TX XXXX XXXX : XX/XX/XXXX TransUnion Consumer Solutions XXXX XXXX XXXX XXXX, PA XXXX XXXX : XXXX Re : Security Freeze Request Dear Sir/Madam, I,

# %%
chunks = retrieve_chunks(
    "What are the common complaints?"
)

print(chunks[0]["text"][:500])
# Out:
# Subject : Dispute of Unauthorized Hard Inquiries on Credit Report XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX, Fl XXXX XX/XX/XXXX Social Security XXXX XX/XX/XXXX Consumer Financial Protection Bureau XXXX XXXX XXXX XXXX, IA XXXX To Whom It May Concern, I am writing to formally dispute unauthorized hard inquiries that have appeared on my credit report. I did not authorize these inquiries, and they are negatively impacting my credit score. Despite previous attempts to resolve this matter with the credi

# %%
def rag_pipeline(question):

    retrieved_chunks = retrieve_chunks(question)

    context = "\n\n".join(
        chunk["text"]
        for chunk in retrieved_chunks
    )

    prompt = f"""
Use the following context to answer the question.

Context:
{context}

Question:
{question}

Answer:
"""

    answer = generate_answer(prompt)

    return answer, retrieved_chunks

# %%
def retrieve_chunks(question, k=3):

    query_embedding = embedding_model.encode(
        [question],
        convert_to_numpy=True
    )

    distances, indices = index.search(
        query_embedding.astype(np.float32),
        k
    )

    retrieved = []

    for idx in indices[0]:
        retrieved.append(metadata[idx])

    return retrieved

# %%
print("embedding_model" in globals())
print("index" in globals())
print("metadata" in globals())
print("retrieve_chunks" in globals())
# Out:
# True
# True
# True
# True

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="distilgpt2"
)

print("Generator loaded successfully")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]

# %%
import gradio as gr
import faiss
import numpy as np
import time

from sentence_transformers import SentenceTransformer
from transformers import pipeline

# ==========================================
# LOAD EMBEDDING MODEL
# ==========================================

embedding_model = SentenceTransformer(
    "all-MiniLM-L6-v2"
)

# ==========================================
# LOAD GENERATION MODEL
# ==========================================

generator = pipeline(
    "text-generation",
    model="distilgpt2"
)

# ==========================================
# BUILD FAISS INDEX
# ==========================================

embeddings = embedding_model.encode(
    documents,
    convert_to_numpy=True,
    show_progress_bar=True
)

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(
    embeddings.astype(np.float32)
)

metadata = [
    {"text": doc}
    for doc in documents
]

# ==========================================
# RETRIEVAL FUNCTION
# ==========================================

def retrieve_chunks(question, k=3):

    query_embedding = embedding_model.encode(
        [question],
        convert_to_numpy=True
    )

    distances, indices = index.search(
        query_embedding.astype(np.float32),
        k
    )

    results = []

    for idx in indices[0]:
        results.append(metadata[idx])

    return results

# ==========================================
# ANSWER GENERATION
# ==========================================

def generate_answer(prompt):

    result = generator(
        prompt,
        max_new_tokens=150,
        do_sample=False,
        truncation=True
    )

    generated_text = result[0]["generated_text"]

    return generated_text.replace(prompt, "").strip()

# ==========================================
# RAG PIPELINE
# ==========================================

def rag_pipeline(question):

    retrieved_chunks = retrieve_chunks(
        question,
        k=3
    )

    context = "\n\n".join(
        chunk["text"]
        for chunk in retrieved_chunks
    )

    prompt = f"""
You are an assistant that answers questions using customer complaint records.

Complaint Records:
{context}

Question:
{question}

Provide a concise answer based only on the complaint records.
"""

    answer = generate_answer(prompt)

    return answer, retrieved_chunks

# ==========================================
# STREAMING
# ==========================================

def ask_question(question):

    answer, retrieved_chunks = rag_pipeline(question)

    sources = "\n\n".join(
        [
            f"Source {i+1}:\n{chunk['text'][:500]}"
            for i, chunk in enumerate(retrieved_chunks)
        ]
    )

    partial_answer = ""

    for word in answer.split():
        partial_answer += word + " "
        time.sleep(0.03)
        yield partial_answer, sources

# ==========================================
# CLEAR
# ==========================================

def clear_all():
    return "", "", ""

# ==========================================
# UI
# ==========================================

with gr.Blocks(title="Complaint RAG Chatbot") as demo:

    gr.Markdown("# Complaint RAG Chatbot")

    gr.Markdown(
        """
Ask questions about customer complaints.

Features:
- AI-generated answers
- Source transparency
- Streaming responses
- Clear button
        """
    )

    question_input = gr.Textbox(
        label="Question",
        placeholder="What are the common complaints about credit reporting?"
    )

    with gr.Row():
        ask_btn = gr.Button("Ask")
        clear_btn = gr.Button("Clear")

    answer_output = gr.Textbox(
        label="AI Generated Answer",
        lines=8
    )

    source_output = gr.Textbox(
        label="Retrieved Sources",
        lines=12
    )

    ask_btn.click(
        fn=ask_question,
        inputs=question_input,
        outputs=[
            answer_output,
            source_output
        ]
    )

    clear_btn.click(
        fn=clear_all,
        outputs=[
            question_input,
            answer_output,
            source_output
        ]
    )

demo.launch()
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 21
#      17 # ==========================================
#      18 # LOAD GENERATION MODEL
#      19 # ==========================================
#      20
# ---> 21 generator = pipeline(
#      22     "text2text-generation",
#      23     model="google/flan-t5-base"
#      24 )
#
# File ~\rag-complaint-chatbo\venv\Lib\site-packages\transformers\pipelines\__init__.py:974, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     967         pipeline_class = get_class_from_dynamic_module(
#     968             class_ref,
#     969             model,
#     970             code_revision=code_revision,
#     971             **hub_kwargs,
#     972         )
#     973 else:
# --> 974     normalized_task, targeted_task, task_options = check_task(task)
#     975     if pipeline_class is None:
#     976         pipeline_class = targeted_task["impl"]
#
# File ~\rag-complaint-chatbo\venv\Lib\site-packages\transformers\pipelines\__init__.py:359, in check_task(task)
#     323 def check_task(task: str) -> tuple[str, dict, Any]:
#     324     """
#     325     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     326     default models if they exist.
#    (...)    357
#     358     """
# --> 359     return PIPELINE_REGISTRY.check_task(task)
#
# File ~\rag-complaint-chatbo\venv\Lib\site-packages\transformers\pipelines\base.py:1350, in PipelineRegistry.check_task(self, task)
#    1347     targeted_task = self.supported_tasks[task]
#    1348     return task, targeted_task, None
# -> 1350 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task text2text-generation, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
[name for name in globals() if callable(globals()[name])]
# Out:
# ['get_ipython',
#  'exit',
#  'quit',
#  'open',
#  'chat_with_rag',
#  'interface',
#  'rag_app',
#  'demo',
#  'respond',
#  'PromptTemplate',
#  'RunnablePassthrough',
#  'StrOutputParser',
#  'format_docs',
#  'answer_question',
#  'rag_pipeline',
#  'ask_question',
#  'clear_all']

# %%
print(type(rag_pipeline))
# Out:
# <class 'function'>

# %%
import inspect

print(inspect.getsource(rag_pipeline))
# Out:
# def rag_pipeline(question):
#     """
#     Replace with your existing RAG implementation.
#     Should return:
#         answer (str)
#         retrieved_chunks (list)
#     """
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = f"""
#     Use the following context to answer the question.
#
#     Context:
#     {context}
#
#     Question:
#     {question}
#
#     Answer:
#     """
#
#     answer = generate_answer(prompt)
#
#     return answer, retrieved_chunks

# %%
print(type(rag_pipeline))
# Out:
# <class 'function'>

# %%
import inspect

print(inspect.getsource(rag_pipeline))
# Out:
# def rag_pipeline(question):
#     """
#     Replace with your existing RAG implementation.
#     Should return:
#         answer (str)
#         retrieved_chunks (list)
#     """
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = f"""
#     Use the following context to answer the question.
#
#     Context:
#     {context}
#
#     Question:
#     {question}
#
#     Answer:
#     """
#
#     answer = generate_answer(prompt)
#
#     return answer, retrieved_chunks

# %%
# %history -n
# Out:
#    1:
# import gradio as gr
#
# def chat_with_rag(question):
#     try:
#         answer = rag_pipeline(question)
#         return answer
#     except Exception as e:
#         return f"Error: {str(e)}"
#
# interface = gr.Interface(
#     fn=chat_with_rag,
#     inputs=gr.Textbox(
#         lines=2,
#         placeholder="Ask a question about the complaint dataset..."
#     ),
#     outputs=gr.Textbox(
#         lines=10,
#         label="Answer"
#     ),
#     title="Complaint Analysis RAG System",
#     description="Ask questions about the complaint dataset using Retrieval-Augmented Generation (RAG)."
# )
#
# interface.launch()
#    2: !pip install gradio
#    3:
# import gradio as gr
#
# def chat_with_rag(question):
#     try:
#         answer = rag_pipeline(question)
#         return answer
#     except Exception as e:
#         return f"Error: {str(e)}"
#
# interface = gr.Interface(
#     fn=chat_with_rag,
#     inputs=gr.Textbox(
#         lines=2,
#         placeholder="Ask a question about the complaint dataset..."
#     ),
#     outputs=gr.Textbox(
#         lines=10,
#         label="Answer"
#     ),
#     title="Complaint Analysis RAG System",
#     description="Ask questions about the complaint dataset using Retrieval-Augmented Generation (RAG)."
# )
#
# interface.launch()
#    4:
# import gradio as gr
#
# def rag_app(question):
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     answer = rag_pipeline(question)
#
#     sources = "\n\n".join(
#         chunk["text"][:300]
#         for chunk in retrieved_chunks[:2]
#     )
#
#     return answer, sources
#
# demo = gr.Interface(
#     fn=rag_app,
#     inputs=gr.Textbox(
#         label="Question",
#         placeholder="Enter your question..."
#     ),
#     outputs=[
#         gr.Textbox(label="Generated Answer"),
#         gr.Textbox(label="Retrieved Sources")
#     ],
#     title="Customer Complaint RAG Assistant",
#     description="Retrieves relevant complaint records and generates answers."
# )
#
# demo.launch()
#    5:
# import gradio as gr
#
# def respond(message, history):
#     answer = rag_pipeline(message)
#     return answer
#
# demo = gr.ChatInterface(
#     fn=respond,
#     title="Customer Complaint RAG Chatbot"
# )
#
# demo.launch()
#    6: print(rag_pipeline)
#    7: %whos
#    8:
# import gradio as gr
#
# def respond(message, history):
#     """
#     Standardized Gradio chat handler.
#     Extracts the clean user question string, runs the RAG chain,
#     and returns a clean string back to the UI interface.
#     """
#     try:
#         # 1. Execute your end-to-end RAG pipeline using the clean message string
#         # (Assuming rag_chain is your pipeline built with the updated strict prompt)
#         ai_response = rag_chain.invoke(message)
#
#         # 2. Return the clean text response directly
#         return ai_response
#
#     except Exception as e:
#         return f"System Error processing query: {str(e)}"
#
# # Initialize the clean ChatInterface wrapper
# demo = gr.ChatInterface(
#     fn=respond,
#     title="CrediTrust Consumer Complaint Intelligence Portal",
#     description="Analyze customer narrative trends and query localized vector contexts securely.",
#     theme="soft"
# )
#
# # Launch the clean application interface
# if __name__ == "__main__":
#     demo.launch()
#    9:
# import gradio as gr
#
# def respond(message, history):
#     """
#     Standardized Gradio chat handler.
#     Extracts the clean user question string, runs the RAG chain,
#     and returns a clean string back to the UI interface.
#     """
#     try:
#         # 1. Execute your end-to-end RAG pipeline using the clean message string
#         # (Assuming rag_chain is your pipeline built with the updated strict prompt)
#         ai_response = rag_chain.invoke(message)
#
#         # 2. Return the clean text response directly
#         return ai_response
#
#     except Exception as e:
#         return f"System Error processing query: {str(e)}"
#
# # Initialize the clean ChatInterface wrapper
# # Initialize the clean ChatInterface wrapper without the theme parameter
# demo = gr.ChatInterface(
#     fn=respond,
#     title="CrediTrust Consumer Complaint Intelligence Portal",
#     description="Analyze customer narrative trends and query localized vector contexts securely."
# )
#
# if __name__ == "__main__":
#     demo.launch()
#   10:
# import gradio as gr
# from langchain_core.prompts import PromptTemplate
# from langchain_core.runnables import RunnablePassthrough
# from langchain_core.output_parsers import StrOutputParser
#
# # ==========================================
# # 1. THE FIXED PRODUCTION PROMPT TEMPLATE
# # ==========================================
# # This template explicitly blocks multiple-choice formatting loops
# RAG_PROMPT_TEMPLATE = """
# You are an expert consumer compliance and financial analyst assistant for CrediTrust.
# Your task is to provide a comprehensive, natural language summary answering the user's question based strictly on the retrieved complaint excerpts below.
#
# CRITICAL DISCIPLINE INSTRUCTIONS:
# 1. You must answer in full, descriptive, narrative sentences.
# 2. Do NOT under any circumstances output standalone multiple-choice markers, symbols, letters, or numbers (e.g., do NOT output 'a).', 'i.', '(ii)', or 'Option A').
# 3. Ignore broken sentence structures or fragments in the source text; extract and summarize the underlying consumer complaints explicitly.
# 4. If the retrieved context doesn't contain enough factual evidence to answer, state: "I do not have enough specific context from the retrieved complaints to answer this question."
#
# Retrieved Complaint Context:
# ---------------------
# {context}
# ---------------------
#
# User Question: {question}
#
# Detailed Analytical Answer:
# """
#
# prompt = PromptTemplate(
#     input_variables=["context", "question"],
#     template=RAG_PROMPT_TEMPLATE
# )
#
# # ==========================================
# # 2. DATA FORMATTING LAYER
# # ==========================================
# def format_docs(docs):
#     """Formats retrieved document chunks cleanly and binds metadata."""
#     formatted_chunks = []
#     for i, doc in enumerate(docs, 1):
#         chunk_text = (
#             f"[Source {i}] Product: {doc.metadata.get('product_category', 'Credit card')}\n"
#             f"Content: {doc.page_content}\n"
#         )
#         formatted_chunks.append(chunk_text)
#     return "\n---\n".join(formatted_chunks)
#
# # ==========================================
# # 3. LLM CONFIGURATION & PIPELINE
# # ==========================================
# # NOTE: Ensure your LLM model wrapper is initialized here (e.g., via Hugging Face or LangChain)
# # We inject precise generation configurations to prevent structural clipping loops.
# llm.generation_config = {
#     "max_new_tokens": 256,   # Gives the model a healthy token budget to generate text
#     "temperature": 0.1,      # Lower temperature forces precise, deterministic extraction
#     "do_sample": False       # Stops the model from wandering off into pattern games
# }
#
# # Construct the robust executable RAG chain
# # (Assuming your vector store retriever variable is named 'retriever')
# rag_chain = (
#     {"context": retriever | format_docs, "question": RunnablePassthrough()}
#     | prompt
#     | llm
#     | StrOutputParser()
# )
#
# # ==========================================
# # 4. CLEAN GRADIO UI IMPLEMENTATION
# # ==========================================
# def respond(message, history):
#     """
#     Standardized Gradio chat handler routing clean string messages to the pipeline.
#     """
#     try:
#         # Sanitize and extract the clean user query string from the interface input
#         clean_query = str(message).strip()
#
#         if not clean_query:
#             return "Please enter a valid question regarding customer complaints."
#
#         # Execute the fortified generation chain
#         ai_response = rag_chain.invoke(clean_query)
#         return ai_response
#
#     except Exception as e:
#         return f"System Error processing query: {str(e)}"
#
# # Render and launch the interface safely wrapped inside a themed Block
# with gr.Blocks(theme="soft") as demo:
#     gr.ChatInterface(
#         fn=respond,
#         title="CrediTrust Consumer Complaint Intelligence Portal",
#         description="Analyze customer narrative trends and query localized vector contexts securely.",
#     )
#
# if __name__ == "__main__":
#     # Launch the interface
#     demo.launch(share=False)
#   11:
# ```python
# import gradio as gr
#
# prompt_template = """
# Use the following context to answer the question.
#
# Context:
# {context}
#
# Question:
# {question}
#
# Answer:
# """
#
# def answer_question(question):
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = prompt_template.format(
#         context=context,
#         question=question
#     )
#
#     answer = generate_answer(prompt)
#
#     # Display top retrieved sources
#     sources = "\n\n".join(
#         [
#             f"Source {i+1}:\n{chunk['text']}"
#             for i, chunk in enumerate(retrieved_chunks[:3])
#         ]
#     )
#
#     return answer, sources
#
#
# def clear_fields():
#     return "", "", ""
#
#
# with gr.Blocks(title="Complaint RAG Chatbot") as demo:
#
#     gr.Markdown("# Complaint RAG Chatbot")
#     gr.Markdown(
#         "Ask questions about customer complaints. "
#         "The system shows both the answer and the supporting source documents."
#     )
#
#     question_input = gr.Textbox(
#         label="Question",
#         placeholder="Enter your question..."
#     )
#
#     with gr.Row():
#         ask_btn = gr.Button("Ask")
#         clear_btn = gr.Button("Clear")
#
#     answer_output = gr.Textbox(
#         label="Generated Answer",
#         lines=8
#     )
#
#     sources_output = gr.Textbox(
#         label="Retrieved Sources",
#         lines=12
#     )
#
#     ask_btn.click(
#         fn=answer_question,
#         inputs=question_input,
#         outputs=[answer_output, sources_output]
#     )
#
#     clear_btn.click(
#         fn=clear_fields,
#         outputs=[
#             question_input,
#             answer_output,
#             sources_output
#         ]
#     )
#
# demo.launch()
# ```
#   12:
#
# import gradio as gr
#
# prompt_template = """
# Use the following context to answer the question.
#
# Context:
# {context}
#
# Question:
# {question}
#
# Answer:
# """
#
# def answer_question(question):
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = prompt_template.format(
#         context=context,
#         question=question
#     )
#
#     answer = generate_answer(prompt)
#
#     # Display top retrieved sources
#     sources = "\n\n".join(
#         [
#             f"Source {i+1}:\n{chunk['text']}"
#             for i, chunk in enumerate(retrieved_chunks[:3])
#         ]
#     )
#
#     return answer, sources
#
#
# def clear_fields():
#     return "", "", ""
#
#
# with gr.Blocks(title="Complaint RAG Chatbot") as demo:
#
#     gr.Markdown("# Complaint RAG Chatbot")
#     gr.Markdown(
#         "Ask questions about customer complaints. "
#         "The system shows both the answer and the supporting source documents."
#     )
#
#     question_input = gr.Textbox(
#         label="Question",
#         placeholder="Enter your question..."
#     )
#
#     with gr.Row():
#         ask_btn = gr.Button("Ask")
#         clear_btn = gr.Button("Clear")
#
#     answer_output = gr.Textbox(
#         label="Generated Answer",
#         lines=8
#     )
#
#     sources_output = gr.Textbox(
#         label="Retrieved Sources",
#         lines=12
#     )
#
#     ask_btn.click(
#         fn=answer_question,
#         inputs=question_input,
#         outputs=[answer_output, sources_output]
#     )
#
#     clear_btn.click(
#         fn=clear_fields,
#         outputs=[
#             question_input,
#             answer_output,
#             sources_output
#         ]
#     )
#
# demo.launch()
# ```
#   13:
# import gradio as gr
# from langchain_core.prompts import PromptTemplate
# from langchain_core.runnables import RunnablePassthrough
# from langchain_core.output_parsers import StrOutputParser
#
# # ==========================================
# # 1. THE FIXED PRODUCTION PROMPT TEMPLATE
# # ==========================================
# # This template explicitly blocks multiple-choice formatting loops
# RAG_PROMPT_TEMPLATE = """
# You are an expert consumer compliance and financial analyst assistant for CrediTrust.
# Your task is to provide a comprehensive, natural language summary answering the user's question based strictly on the retrieved complaint excerpts below.
#
# CRITICAL DISCIPLINE INSTRUCTIONS:
# 1. You must answer in full, descriptive, narrative sentences.
# 2. Do NOT under any circumstances output standalone multiple-choice markers, symbols, letters, or numbers (e.g., do NOT output 'a).', 'i.', '(ii)', or 'Option A').
# 3. Ignore broken sentence structures or fragments in the source text; extract and summarize the underlying consumer complaints explicitly.
# 4. If the retrieved context doesn't contain enough factual evidence to answer, state: "I do not have enough specific context from the retrieved complaints to answer this question."
#
# Retrieved Complaint Context:
# ---------------------
# {context}
# ---------------------
#
# User Question: {question}
#
# Detailed Analytical Answer:
# """
#
# prompt = PromptTemplate(
#     input_variables=["context", "question"],
#     template=RAG_PROMPT_TEMPLATE
# )
#
# # ==========================================
# # 2. DATA FORMATTING LAYER
# # ==========================================
# def format_docs(docs):
#     """Formats retrieved document chunks cleanly and binds metadata."""
#     formatted_chunks = []
#     for i, doc in enumerate(docs, 1):
#         chunk_text = (
#             f"[Source {i}] Product: {doc.metadata.get('product_category', 'Credit card')}\n"
#             f"Content: {doc.page_content}\n"
#         )
#         formatted_chunks.append(chunk_text)
#     return "\n---\n".join(formatted_chunks)
#
# # ==========================================
# # 3. LLM CONFIGURATION & PIPELINE
# # ==========================================
# # NOTE: Ensure your LLM model wrapper is initialized here (e.g., via Hugging Face or LangChain)
# # We inject precise generation configurations to prevent structural clipping loops.
# llm.generation_config = {
#     "max_new_tokens": 256,   # Gives the model a healthy token budget to generate text
#     "temperature": 0.1,      # Lower temperature forces precise, deterministic extraction
#     "do_sample": False       # Stops the model from wandering off into pattern games
# }
#
# # Construct the robust executable RAG chain
# # (Assuming your vector store retriever variable is named 'retriever')
# rag_chain = (
#     {"context": retriever | format_docs, "question": RunnablePassthrough()}
#     | prompt
#     | llm
#     | StrOutputParser()
# )
#
# # ==========================================
# # 4. CLEAN GRADIO UI IMPLEMENTATION
# # ==========================================
# def respond(message, history):
#     """
#     Standardized Gradio chat handler routing clean string messages to the pipeline.
#     """
#     try:
#         # Sanitize and extract the clean user query string from the interface input
#         clean_query = str(message).strip()
#
#         if not clean_query:
#             return "Please enter a valid question regarding customer complaints."
#
#         # Execute the fortified generation chain
#         ai_response = rag_chain.invoke(clean_query)
#         return ai_response
#
#     except Exception as e:
#         return f"System Error processing query: {str(e)}"
#
# # Render and launch the interface safely wrapped inside a themed Block
# with gr.Blocks(theme="soft") as demo:
#     gr.ChatInterface(
#         fn=respond,
#         title="CrediTrust Consumer Complaint Intelligence Portal",
#         description="Analyze customer narrative trends and query localized vector contexts securely.",
#     )
#
# if __name__ == "__main__":
#     # Launch the interface
#     demo.launch(share=False)
#   14:
# import gradio as gr
# from langchain_core.prompts import PromptTemplate
# from langchain_core.runnables import RunnablePassthrough
# from langchain_core.output_parsers import StrOutputParser
#
# # ==========================================
# # 1. THE FIXED PRODUCTION PROMPT TEMPLATE
# # ==========================================
# # This template explicitly blocks multiple-choice formatting loops
# RAG_PROMPT_TEMPLATE = """
# You are an expert consumer compliance and financial analyst assistant for CrediTrust.
# Your task is to provide a comprehensive, natural language summary answering the user's question based strictly on the retrieved complaint excerpts below.
#
# CRITICAL DISCIPLINE INSTRUCTIONS:
# 1. You must answer in full, descriptive, narrative sentences.
# 2. Do NOT under any circumstances output standalone multiple-choice markers, symbols, letters, or numbers (e.g., do NOT output 'a).', 'i.', '(ii)', or 'Option A').
# 3. Ignore broken sentence structures or fragments in the source text; extract and summarize the underlying consumer complaints explicitly.
# 4. If the retrieved context doesn't contain enough factual evidence to answer, state: "I do not have enough specific context from the retrieved complaints to answer this question."
#
# Retrieved Complaint Context:
# ---------------------
# {context}
# ---------------------
#
# User Question: {question}
#
# Detailed Analytical Answer:
# """
#
# prompt = PromptTemplate(
#     input_variables=["context", "question"],
#     template=RAG_PROMPT_TEMPLATE
# )
#
# # ==========================================
# # 2. DATA FORMATTING LAYER
# # ==========================================
# def format_docs(docs):
#     """Formats retrieved document chunks cleanly and binds metadata."""
#     formatted_chunks = []
#     for i, doc in enumerate(docs, 1):
#         chunk_text = (
#             f"[Source {i}] Product: {doc.metadata.get('product_category', 'Credit card')}\n"
#             f"Content: {doc.page_content}\n"
#         )
#         formatted_chunks.append(chunk_text)
#     return "\n---\n".join(formatted_chunks)
#
# # ==========================================
# # 3. LLM CONFIGURATION & PIPELINE
# # ==========================================
# # NOTE: Ensure your LLM model wrapper is initialized here (e.g., via Hugging Face or LangChain)
# # We inject precise generation configurations to prevent structural clipping loops.
# llm.generation_config = {
#     "max_new_tokens": 256,
#     "temperature": 0.1,
#     "do_sample": False
# }
#
# # Construct the robust executable RAG chain
# # (Assuming your vector store retriever variable is named 'retriever')
# rag_chain = (
#     {"context": retriever | format_docs, "question": RunnablePassthrough()}
#     | prompt
#     | llm
#     | StrOutputParser()
# )
#
# # ==========================================
# # 4. CLEAN GRADIO UI IMPLEMENTATION
# # ==========================================
# def respond(message, history):
#     """
#     Standardized Gradio chat handler routing clean string messages to the pipeline.
#     """
#     try:
#         # Sanitize and extract the clean user query string from the interface input
#         clean_query = str(message).strip()
#
#         if not clean_query:
#             return "Please enter a valid question regarding customer complaints."
#
#         # Execute the fortified generation chain
#         ai_response = rag_chain.invoke(clean_query)
#         return ai_response
#
#     except Exception as e:
#         return f"System Error processing query: {str(e)}"
#
# # Render and launch the interface safely wrapped inside a themed Block
# with gr.Blocks(theme="soft") as demo:
#     gr.ChatInterface(
#         fn=respond,
#         title="CrediTrust Consumer Complaint Intelligence Portal",
#         description="Analyze customer narrative trends and query localized vector contexts securely.",
#     )
#
# if __name__ == "__main__":
#     # Launch the interface
#     demo.launch(share=False)
#   15:
# import gradio as gr
#
# # Function that calls your RAG system
# def answer_question(question):
#     try:
#         answer = rag_pipeline(question)
#         return answer
#     except Exception as e:
#         return f"Error: {e}"
#
# with gr.Blocks(title="Complaint RAG Chatbot") as demo:
#
#     gr.Markdown("# Complaint RAG Chatbot")
#     gr.Markdown("Ask questions about the complaint dataset.")
#
#     question_input = gr.Textbox(
#         label="Your Question",
#         placeholder="Enter your question here..."
#     )
#
#     ask_button = gr.Button("Ask")
#
#     answer_output = gr.Textbox(
#         label="AI Generated Answer",
#         lines=8
#     )
#
#     ask_button.click(
#         fn=answer_question,
#         inputs=question_input,
#         outputs=answer_output
#     )
#
# demo.launch()
#   16:
# ```python
# import gradio as gr
# import time
#
# prompt_template = """
# Use the following context to answer the question.
#
# Context:
# {context}
#
# Question:
# {question}
#
# Answer:
# """
#
# def rag_with_sources(question):
#
#     # Retrieve relevant chunks
#     retrieved_chunks = retrieve_chunks(question)
#
#     # Build context
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     # Build prompt
#     prompt = prompt_template.format(
#         context=context,
#         question=question
#     )
#
#     # Generate answer
#     answer = generate_answer(prompt)
#
#     # Prepare sources for display
#     sources = "\n\n".join([
#         f"Source {i+1}:\n{chunk['text']}"
#         for i, chunk in enumerate(retrieved_chunks[:3])
#     ])
#
#     return answer, sources
#
#
# def rag_with_streaming(question):
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = prompt_template.format(
#         context=context,
#         question=question
#     )
#
#     answer = generate_answer(prompt)
#
#     sources = "\n\n".join([
#         f"Source {i+1}:\n{chunk['text']}"
#         for i, chunk in enumerate(retrieved_chunks[:3])
#     ])
#
#     partial_answer = ""
#
#     for word in answer.split():
#         partial_answer += word + " "
#         time.sleep(0.02)
#         yield partial_answer, sources
#
#
# def clear_all():
#     return "", "", ""
#
#
# with gr.Blocks(title="Complaint RAG Chatbot") as demo:
#
#     gr.Markdown("# Complaint RAG Chatbot")
#     gr.Markdown(
#         "Ask questions about customer complaints. "
#         "The chatbot displays both answers and supporting sources."
#     )
#
#     question_input = gr.Textbox(
#         label="Your Question",
#         placeholder="Enter a question..."
#     )
#
#     with gr.Row():
#         ask_button = gr.Button("Ask")
#         clear_button = gr.Button("Clear")
#
#     answer_output = gr.Textbox(
#         label="AI Generated Answer",
#         lines=8
#     )
#
#     sources_output = gr.Textbox(
#         label="Retrieved Sources",
#         lines=10
#     )
#
#     # Use rag_with_sources for normal mode
#     # Use rag_with_streaming for streaming mode
#     ask_button.click(
#         fn=rag_with_streaming,
#         inputs=question_input,
#         outputs=[answer_output, sources_output]
#     )
#
#     clear_button.click(
#         fn=clear_all,
#         outputs=[
#             question_input,
#             answer_output,
#             sources_output
#         ]
#     )
#
# demo.launch()
# ```
#   17:
# ```python
# import gradio as gr
# import time
#
# # ==========================================
# # RAG FUNCTION
# # ==========================================
#
# def rag_pipeline(question):
#     """
#     Replace with your existing RAG implementation.
#     Should return:
#         answer (str)
#         retrieved_chunks (list)
#     """
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = f"""
#     Use the following context to answer the question.
#
#     Context:
#     {context}
#
#     Question:
#     {question}
#
#     Answer:
#     """
#
#     answer = generate_answer(prompt)
#
#     return answer, retrieved_chunks
#
#
# # ==========================================
# # STREAMING RESPONSE
# # ==========================================
#
# def ask_question(question):
#
#     try:
#         answer, retrieved_chunks = rag_pipeline(question)
#
#         sources = "\n\n".join(
#             [
#                 f"Source {i+1}:\n{chunk['text']}"
#                 for i, chunk in enumerate(retrieved_chunks[:3])
#             ]
#         )
#
#         partial = ""
#
#         for word in answer.split():
#             partial += word + " "
#             time.sleep(0.02)
#             yield partial, sources
#
#     except Exception as e:
#         yield f"Error: {str(e)}", ""
#
#
# # ==========================================
# # CLEAR FUNCTION
# # ==========================================
#
# def clear_all():
#     return "", "", ""
#
#
# # ==========================================
# # GRADIO UI
# # ==========================================
#
# with gr.Blocks(title="Complaint RAG Chatbot") as demo:
#
#     gr.Markdown("# Complaint RAG Chatbot")
#
#     gr.Markdown(
#         """
#         Ask questions about customer complaints.
#         The chatbot displays both the generated answer
#         and the retrieved source documents.
#         """
#     )
#
#     question_input = gr.Textbox(
#         label="Your Question",
#         placeholder="Why are customers complaining about unauthorized credit card charges?"
#     )
#
#     with gr.Row():
#         ask_button = gr.Button("Ask")
#         clear_button = gr.Button("Clear")
#
#     answer_output = gr.Textbox(
#         label="AI Generated Answer",
#         lines=10
#     )
#
#     sources_output = gr.Textbox(
#         label="Retrieved Sources",
#         lines=12
#     )
#
#     ask_button.click(
#         fn=ask_question,
#         inputs=question_input,
#         outputs=[
#             answer_output,
#             sources_output
#         ]
#     )
#
#     clear_button.click(
#         fn=clear_all,
#         outputs=[
#             question_input,
#             answer_output,
#             sources_output
#         ]
#     )
#
# demo.launch()
# ```
#   18:
#
# import gradio as gr
# import time
#
# # ==========================================
# # RAG FUNCTION
# # ==========================================
#
# def rag_pipeline(question):
#     """
#     Replace with your existing RAG implementation.
#     Should return:
#         answer (str)
#         retrieved_chunks (list)
#     """
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = f"""
#     Use the following context to answer the question.
#
#     Context:
#     {context}
#
#     Question:
#     {question}
#
#     Answer:
#     """
#
#     answer = generate_answer(prompt)
#
#     return answer, retrieved_chunks
#
#
# # ==========================================
# # STREAMING RESPONSE
# # ==========================================
#
# def ask_question(question):
#
#     try:
#         answer, retrieved_chunks = rag_pipeline(question)
#
#         sources = "\n\n".join(
#             [
#                 f"Source {i+1}:\n{chunk['text']}"
#                 for i, chunk in enumerate(retrieved_chunks[:3])
#             ]
#         )
#
#         partial = ""
#
#         for word in answer.split():
#             partial += word + " "
#             time.sleep(0.02)
#             yield partial, sources
#
#     except Exception as e:
#         yield f"Error: {str(e)}", ""
#
#
# # ==========================================
# # CLEAR FUNCTION
# # ==========================================
#
# def clear_all():
#     return "", "", ""
#
#
# # ==========================================
# # GRADIO UI
# # ==========================================
#
# with gr.Blocks(title="Complaint RAG Chatbot") as demo:
#
#     gr.Markdown("# Complaint RAG Chatbot")
#
#     gr.Markdown(
#         """
#         Ask questions about customer complaints.
#         The chatbot displays both the generated answer
#         and the retrieved source documents.
#         """
#     )
#
#     question_input = gr.Textbox(
#         label="Your Question",
#         placeholder="Why are customers complaining about unauthorized credit card charges?"
#     )
#
#     with gr.Row():
#         ask_button = gr.Button("Ask")
#         clear_button = gr.Button("Clear")
#
#     answer_output = gr.Textbox(
#         label="AI Generated Answer",
#         lines=10
#     )
#
#     sources_output = gr.Textbox(
#         label="Retrieved Sources",
#         lines=12
#     )
#
#     ask_button.click(
#         fn=ask_question,
#         inputs=question_input,
#         outputs=[
#             answer_output,
#             sources_output
#         ]
#     )
#
#     clear_button.click(
#         fn=clear_all,
#         outputs=[
#             question_input,
#             answer_output,
#             sources_output
#         ]
#     )
#
# demo.launch()
#   19: print("retrieve_chunks" in globals())
#   20: [name for name in globals() if callable(globals()[name])]
#   21: print(type(rag_pipeline))
#   22:
# response = rag_pipeline.invoke(
#     "Why are customers complaining about unauthorized charges?"
# )
#
# print(response)
#   23:
# import inspect
#
# print(inspect.getsource(rag_pipeline))
#   24: print(type(rag_pipeline))
#   25:
#
# import gradio as gr
# import time
#
# # ==========================================
# # RAG FUNCTION
# # ==========================================
#
# def rag_pipeline(question):
#     """
#     Replace with your existing RAG implementation.
#     Should return:
#         answer (str)
#         retrieved_chunks (list)
#     """
#
#     retrieved_chunks = retrieve_chunks(question)
#
#     context = "\n\n".join(
#         chunk["text"] for chunk in retrieved_chunks
#     )
#
#     prompt = f"""
#     Use the following context to answer the question.
#
#     Context:
#     {context}
#
#     Question:
#     {question}
#
#     Answer:
#     """
#
#     answer = generate_answer(prompt)
#
#     return answer, retrieved_chunks
#
#
# # ==========================================
# # STREAMING RESPONSE
# # ==========================================
#
# def ask_question(question):
#
#     try:
#         answer, retrieved_chunks = rag_pipeline(question)
#
#         sources = "\n\n".join(
#             [
#                 f"Source {i+1}:\n{chunk['text']}"
#                 for i, chunk in enumerate(retrieved_chunks[:3])
#             ]
#         )
#
#         partial = ""
#
#         for word in answer.split():
#             partial += word + " "
#             time.sleep(0.02)
#             yield partial, sources
#
#     except Exception as e:
#         yield f"Error: {str(e)}", ""
#
#
# # ==========================================
# # CLEAR FUNCTION
# # ==========================================
#
# def clear_all():
#     return "", "", ""
#
#
# # ==========================================
# # GRADIO UI
# # ==========================================
#
# with gr.Blocks(title="Complaint RAG Chatbot") as demo:
#
#     gr.Markdown("# Complaint RAG Chatbot")
#
#     gr.Markdown(
#         """
#         Ask questions about customer complaints.
#         The chatbot displays both the generated answer
#         and the retrieved source documents.
#         """
#     )
#
#     question_input = gr.Textbox(
#         label="Your Question",
#         placeholder="Why are customers complaining about unauthorized credit card charges?"
#     )
#
#     with gr.Row():
#         ask_button = gr.Button("Ask")
#         clear_button = gr.Button("Clear")
#
#     answer_output = gr.Textbox(
#         label="AI Generated Answer",
#         lines=10
#     )
#
#     sources_output = gr.Textbox(
#         label="Retrieved Sources",
#         lines=12
#     )
#
#     ask_button.click(
#         fn=ask_question,
#         inputs=question_input,
#         outputs=[
#             answer_output,
#             sources_output
#         ]
#     )
#
#     clear_button.click(
#         fn=clear_all,
#         outputs=[
#             question_input,
#             answer_output,
#             sources_output
#         ]
#     )
#
# demo.launch()
#   26:
# response = rag_pipeline.invoke(
#     "Why are customers complaining about unauthorized charges?"
# )
#
# print(response)
#   27:
# import inspect
#
# print(inspect.getsource(rag_pipeline))
#   28: %history -n

# %%
print("index" in globals())
print("metadata" in globals())
print("embedding_model" in globals())
# Out:
# False
# False
# False

# %%
response = rag_pipeline.invoke(
    "Why are customers complaining about unauthorized charges?"
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 response = rag_pipeline.invoke(
#       2     "Why are customers complaining about unauthorized charges?"
#       3 )
#       4
#
# AttributeError: 'function' object has no attribute 'invoke'

# %%
# %whos
# Out:
# Variable        Type             Data/Info
# ------------------------------------------
# chat_with_rag   function         <function chat_with_rag at 0x0000016E2F2A43B0>
# demo            ChatInterface    Gradio Blocks instance: 2<...>ct at 0x0000016E7D2FD310>
# gr              module           <module 'gradio' from 'C:<...>es\\gradio\\__init__.py'>
# interface       Interface        Gradio Interface for: cha<...>ct at 0x0000016E3AF19BD0>
# rag_app         function         <function rag_app at 0x0000016E3CDF9590>
# respond         function         <function respond at 0x0000016E7D1362A0>

# %%
print(rag_pipeline)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(rag_pipeline)
#
# NameError: name 'rag_pipeline' is not defined

# %%
```python
import gradio as gr
import time

prompt_template = """
Use the following context to answer the question.

Context:
{context}

Question:
{question}

Answer:
"""

def rag_with_sources(question):

    # Retrieve relevant chunks
    retrieved_chunks = retrieve_chunks(question)

    # Build context
    context = "\n\n".join(
        chunk["text"] for chunk in retrieved_chunks
    )

    # Build prompt
    prompt = prompt_template.format(
        context=context,
        question=question
    )

    # Generate answer
    answer = generate_answer(prompt)

    # Prepare sources for display
    sources = "\n\n".join([
        f"Source {i+1}:\n{chunk['text']}"
        for i, chunk in enumerate(retrieved_chunks[:3])
    ])

    return answer, sources


def rag_with_streaming(question):

    retrieved_chunks = retrieve_chunks(question)

    context = "\n\n".join(
        chunk["text"] for chunk in retrieved_chunks
    )

    prompt = prompt_template.format(
        context=context,
        question=question
    )

    answer = generate_answer(prompt)

    sources = "\n\n".join([
        f"Source {i+1}:\n{chunk['text']}"
        for i, chunk in enumerate(retrieved_chunks[:3])
    ])

    partial_answer = ""

    for word in answer.split():
        partial_answer += word + " "
        time.sleep(0.02)
        yield partial_answer, sources


def clear_all():
    return "", "", ""


with gr.Blocks(title="Complaint RAG Chatbot") as demo:

    gr.Markdown("# Complaint RAG Chatbot")
    gr.Markdown(
        "Ask questions about customer complaints. "
        "The chatbot displays both answers and supporting sources."
    )

    question_input = gr.Textbox(
        label="Your Question",
        placeholder="Enter a question..."
    )

    with gr.Row():
        ask_button = gr.Button("Ask")
        clear_button = gr.Button("Clear")

    answer_output = gr.Textbox(
        label="AI Generated Answer",
        lines=8
    )

    sources_output = gr.Textbox(
        label="Retrieved Sources",
        lines=10
    )

    # Use rag_with_sources for normal mode
    # Use rag_with_streaming for streaming mode
    ask_button.click(
        fn=rag_with_streaming,
        inputs=question_input,
        outputs=[answer_output, sources_output]
    )

    clear_button.click(
        fn=clear_all,
        outputs=[
            question_input,
            answer_output,
            sources_output
        ]
    )

demo.launch()
```
# Out:
#   Cell In[16], line 1
#     ```python
#     ^
# SyntaxError: invalid syntax

# %%
import gradio as gr

def respond(message, history):
    answer = rag_pipeline(message)
    return answer

demo = gr.ChatInterface(
    fn=respond,
    title="Customer Complaint RAG Chatbot"
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\routes.py:1379: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Traceback (most recent call last):
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\queueing.py", line 867, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\route_utils.py", line 386, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<11 lines>...
#     )
#     ^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\blocks.py", line 2280, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#     )
#     ^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\blocks.py", line 1655, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\utils.py", line 1028, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\chat_interface.py", line 545, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\gradio\chat_interface.py", line 934, in _submit_fn
#     response = await run_sync(self.fn, *inputs, limiter=self.limiter)  # type: ignore
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\anyio\to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         func, args, abandon_on_cancel=abandon_on_cancel, limiter=limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2592, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Soret\rag-complaint-chatbo\venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 1029, in run
#     result = context.run(func, *args)
#   File "C:\Users\Soret\AppData\Local\Temp\ipykernel_7056\642316611.py", line 4, in respond
#     answer = rag_pipeline(message)
#              ^^^^^^^^^^^^
# NameError: name 'rag_pipeline' is not defined
